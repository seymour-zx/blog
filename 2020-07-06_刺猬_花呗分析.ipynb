# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import random
import numpy as np
#科学计算工具包
import pandas as pd
#数据分析工具包
import matplotlib.pyplot as plt
# matplotlib ：图表绘制工具包

import matplotlib.style as psl
psl.use('seaborn-colorblind')
% matplotlib inline
#设置一个图标风格
#魔法函数

print('导入完成')


x = np.arange(100)
y = np.random.randn(100)
plt.plot(x,y)
plt.title(u'测试图表',fontproperties='SimHei',fontsize = 20)
#a = np.arange(0.0,5.0,0.02)
plt.xlabel('横轴：时间',fontproperties = 'SimHei',fontsize = 20)
plt.ylabel('纵轴：振幅',fontproperties = 'SimHei',fontsize = 20)
#plt.plot(a,np.cos(2*np.pi*a),'r--')
#plt.show()
plt.grid()

import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# 导入完成
# D:\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family'] = 'SimHei'
plt.plot([3,1,4,5,2])
plt.ylabel("纵轴（值）")
plt.savefig('test2',dpi=600)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.rcParams['font.family'] = 'STSong'
matplotlib.rcParams['font.size'] = 20
a = np.arange(0.0,5.0,0.02)
plt.xlabel('横轴：时间')
plt.ylabel('纵轴：振幅')
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.show()

# %%
#基本生活支出

general_expense = pd.Series(np.random.randint(3000,3501,size =120))

plt.title('基本生活支出')
plt.hist(general_expense,bins = 30)
plt.grid()

# %%
# #coding:utf-8
# import matplotlib
# from matplotlib.font_manager import *
# import matplotlib.pyplot as plt
# myfont = FontProperties(fname='/System/Library/Fonts/PingFang.ttc')
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.plot([-1,2,-5,3])
# plt.title(u'中文',fontproperties=myfont)
# plt.legend((u'头等舱', u'2等舱',u'3等舱'),loc='best',prop=myfont) # sets our legend for our graph.
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# D:\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
# ...

# %%
#购物支出

shopping = pd.Series(np.random.normal(loc=5000,scale = 500,size =120))

plt.title('购物支出')
plt.hist(shopping,bins = 30)
plt.grid()

# %%
#娱乐支出

happy = pd.Series(np.random.randint(400,1200,size =120))

plt.title('娱乐支出')
plt.hist(happy,bins = 30)
plt.grid()

# %%
# 奖金随机函数

def bouns(b_avg):
    # 预设十年的奖金，生成120个随机数
    return pd.Series(np.random.normal(loc = b_avg,scale = 200,size = 120))

x = input('请输入函数均值')
x = int(x)
print('函数构建完成，当奖金均值为',x,'的时候，随机数组为：')
print(bouns(x)[:10]) #输出前十个数

plt.title('奖金随机函数 - 数据分布直方图')
plt.hist(bouns(x),bins = 30)
plt.grid()
# Out:
# 请输入函数均值1500
# 函数构建完成，当奖金均值为 1500 的时候，随机数组为：
# 0    1482.168018
# 1    1545.465424
# 2    1216.440002
# 3    1483.588731
# 4    1585.693709
# 5    1535.464793
# 6    1823.196558
# 7    1025.159070
# 8    1353.161747
# 9    1780.936607
# dtype: float64

# %%
#构建每月净收入模型：净收入 = 月薪 - 五险一金

def final_income():
    df_i = pd.DataFrame({
        '奖金':bouns(x)              
        
        
    })
    df_i['计税部分'] = df_i['奖金'] * 2 
    df_i['约分'] = df_i['奖金'].apply(lambda y:int(y))  # 每个值去运行函数的语句
    return df_i

# %%
result = final_income()

result['奖金'].iloc[:12].plot(kind = 'bar',figsize = (12,6),color = 'blue')
plt.title('月净收入模型 - 前 12 月')
plt.grid()

result.head()
# Out:
#             奖金         计税部分    约分
# 0  1603.216155  3206.432311  1603
# 1  1739.752110  3479.504220  1739
# 2  1541.916260  3083.832520  1541
# 3  1427.051924  2854.103847  1427
# 4  1364.121393  2728.242786  1364

# %%
#pandas 的数据结构 Series  DataFrame

s = pd.Series(np.random.randn(10))
print(s)
# Out:
# 0   -0.559476
# 1   -0.676311
# 2   -0.961057
# 3    0.615282
# 4   -1.994139
# 5   -0.593796
# 6   -3.156983
# 7   -1.307130
# 8    1.609764
# 9   -0.247060
# dtype: float64

# %%
d = pd.DataFrame(np.random.rand(113,5)*20,columns = ['老婆个数','老婆价格','老婆1价格','2老婆价格','老3婆价格'],index = ('a'+str(i) for i in range(1,114)))
print(d)
# Out:
#            老婆个数       老婆价格      老婆1价格      2老婆价格      老3婆价格
# a1     5.664151  18.321422   3.494795   5.150656  18.660250
# a2     6.948275  18.581649  11.467836  15.211399  15.790031
# a3     2.770646  12.306051  18.331703   3.876192  15.336789
# a4    12.857538   3.601113   2.396817   8.031259   9.882593
# a5    19.016031  10.163070  15.673780   0.482136   7.835351
# a6     3.016956  12.779171  12.847142   3.142821  16.335037
# a7    15.785725  11.358130  18.368891  18.926218  17.366506
# a8    19.441693   6.663555   1.792383   0.926735  15.248054
# a9     2.006784  15.674239  13.691941   7.511586   9.763511
# a10   10.551745   5.909536  12.920346   8.553434   0.564136
# a11    5.335896  11.536806   2.350293  14.333455   9.817926
# a12   17.572776   0.237848   5.445880   5.698851  18.731885
# a13    6.175847  13.429140  16.708559   6.473015  10.775237
# a14   11.138941  17.162887  11.877312   1.975360   0.542617
# a15   13.739891  12.514770   4.548687  16.704966  13.520251
# ...

# %%
d.loc['a3']
# Out:
# 老婆个数      2.770646
# 老婆价格     12.306051
# 老婆1价格    18.331703
# 2老婆价格     3.876192
# 老3婆价格    15.336789
# Name: a3, dtype: float64

# %%
d.iloc[4]
# Out:
# 老婆个数     19.016031
# 老婆价格     10.163070
# 老婆1价格    15.673780
# 2老婆价格     0.482136
# 老3婆价格     7.835351
# Name: a5, dtype: float64

# %%
#dd =  pd.DataFrame(np.random.rand(10,2)*20,columns = ['老婆个数','老婆价格'],index = ('a'+str(i) for i in range(1,11)))
dd = pd.DataFrame(np.random.rand(10,2),columns = ['老婆个数','老婆价格'])
dd['老婆个数'].iloc[:5].plot(kind = 'bar',figsize = (14,16),stacked = True ,colormap = 'Blues_r')
dd.head()
print(dd)
# Out:
#        老婆个数      老婆价格
# 0  0.790705  0.294634
# 1  0.455998  0.008290
# 2  0.935577  0.072640
# 3  0.591598  0.893591
# 4  0.730706  0.163357
# 5  0.503233  0.710332
# 6  0.097292  0.815576
# 7  0.972840  0.052297
# 8  0.344025  0.776869
# 9  0.652253  0.629890

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# data = pd.read_excel('sample.xls', sheet_name=0)
# data.head()

data = pd.DataFrame(np.random.rand(20,3), columns=['ExpecVida', 'PIBperCapita', 'PopX1000'])

plt.scatter(x=data['ExpecVida'],
            y=data['PIBperCapita'],
            s=data['PopX1000']*1000,
            c=data['PopX1000'],
            cmap=cm.viridis)


plt.show()

# %%
import matplotlib
matplotlib.colors
matplotlib.axes.Axes.imshow
matplotlib.figure.Figure.text
matplotlib.axes.Axes.set_axis_off

import numpy as np
import matplotlib.pyplot as plt


cmaps = [('Perceptually Uniform Sequential', ['viridis', 'plasma', 'inferno', 'magma', 'cividis']),
         ('Sequential', ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                         'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                         'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', ['binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink','spring', 
                             'summer', 'autumn', 'winter', 'cool', 'Wistia','hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', ['PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu','RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 
                        'bwr', 'seismic']),
         ('Cyclic', ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative', ['Pastel1', 'Pastel2', 'Paired', 'Accent','Dark2', 'Set1', 'Set2', 
                          'Set3','tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', ['flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern','gnuplot', 'gnuplot2', 
                            'CMRmap', 'cubehelix', 'brg','gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar'])]


gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axes = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)

    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        ax.text(-.01, .5, name, va='center', ha='right', fontsize=10,transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8742ca2501be> in <module>()
#      47
#      48 for cmap_category, cmap_list in cmaps:
# ---> 49     plot_color_gradients(cmap_category, cmap_list)
#      50
#      51 plt.show()
#
# <ipython-input-15-8742ca2501be> in plot_color_gradients(cmap_category, cmap_list)
#      38
#      39     for ax, name in zip(axes, cmap_list):
# ---> 40         ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
#      41         ax.text(-.01, .5, name, va='center', ha='right', fontsize=10,transform=ax.transAxes)
#      42
#
# D:\Anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     166         raise ValueError(
#     167             "Colormap %s is not recognized. Possible values are: %s"
# --> 168             % (name, ', '.join(sorted(cmap_d))))
#     169
#     170
#
# ...
