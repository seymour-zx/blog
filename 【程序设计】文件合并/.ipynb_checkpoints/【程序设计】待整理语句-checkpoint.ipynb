# %% [markdown]
# # 程序设计

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-


#主程序区域【】
if __name__ == "__main__":
    
    
#     rootWindow —— tkinter的根窗口
    if True:    
#         根窗口的定期刷新
        def refreshRegularlyRoot():
            if True:
                pass            
            rootWindow.after(5000,refreshRegularlyRoot) #5000毫秒



#         根窗口菜单
        if True:
#             生成根窗口的主菜单栏
            menuRoot = tkinter.Menu( rootWindow )
            
#             生成下拉菜单1
            submenu = tkinter.Menu( menuRoot , tearoff = 0 )
#             在下拉菜单中添加
            submenu.add_command( label = "Open" )
            submenu.add_command( label = "Exit" ,command = lambda:rootWindow.destroy() )            
#             将（下拉菜单1）添加到（菜单）中
            menuRoot.add_cascade( label = "File" , menu = submenu )
            
#             生成下拉菜单2
            submenu = tkinter.Menu( menuRoot , tearoff = 0 )
#             在下拉菜单中添加
            submenu.add_command( label = "Close" )
#             将（下拉菜单1）添加到（菜单）中
            menuRoot.add_cascade( label = "Edit" , menu = submenu )  
            
#             确认（菜单）在主窗口显示
            rootWindow.config( menu = menuRoot )
    

   
    #点击数字按钮时，在显示框的末尾插入
#             def keyboard_click(event):
#                 mylabel1 = tkinter.Label( frame_3 ,text = ("鼠标的位置：" , event.x, event.y ), font=('微软雅黑',14),bg="white",fg="#008080" )
#                 mylabel2 = tkinter.Label( frame_3 ,text = ("敲击的键：" , event.keysym ), font=('微软雅黑',14),bg="white",fg="#008080" )
#                 mylabel1.grid() 
#                 mylabel2.grid() 

#             # 鼠标 在 计算器键盘_3 板块内移动
#             frame_3.bind('<Motion>',keyboard_click)


#             # 按钮 —— Enter
#             frame3_button_numenter = tkinter.Button(frame_3,text = 'Enter')
#             frame3_button_numenter.grid(row =4,column=1,columnspan = 3, padx=5, pady=5)

#             #鼠标离开按钮范围
#             frame3_button_numenter.bind("<Leave>", keyboard_click)
#             #鼠标进入按钮范围
#             frame3_button_numenter.bind("<Enter>",keyboard_click)
#             #鼠标左键单击
#             frame3_button_numenter.bind("<Button-1>",keyboard_click)
#             #鼠标右键单击
#             frame3_button_numenter.bind("<Button-3>",keyboard_click) 

#             #键盘按键
#             frame3_button_numenter.bind('<Key>',keyboard_click)
#             #键盘注焦，键盘按键事件才有效
#             frame3_button_numenter.focus_set()

            
    
# #     f222rame_3 = tkinter.Toplevel( root )
# #     f222rame_3.title("jiojoasjdofjods")
# #     f222rame_3.geometry("250x150")
    
    
    
# #     #点击主窗口 红叉 时，不关闭窗口而 弹出提示框        
# #     import tkinter.messagebox
# #     def close_windows():
# #         tkinter.messagebox.showerror("提示一下","再细细想想~~！")
# #     root.protocol("WM_DELETE_WINDOW",lambda:close_windows())
    
    
# #     vertical1 = tkinter.Scale(root, from_=0 , to = 100)
# #     vertical1.grid()
# #     #水平
# #     horizontal1 = tkinter.Scale(root, from_=0 , to = 300,orient="horizontal")
# #     horizontal1.grid()
    
# #     #单选框
# #     if True:
# #         def show():
# #             malabel12 = tkinter.Label(root, text = var1.get()).grid()
            
# # #         var1 = tkinter.IntVar()
# # #         c = tkinter.Checkbutton(root,text ="Check this box", variable = var1).grid()
# #         var1 = tkinter.StringVar()
# #         c12 = tkinter.Checkbutton(root,text ="Check this box", variable = var1,onvalue = "On",offvalue="Off")
# #         c12.deselect()
# #         c12.grid()

# #         d = tkinter.Button(root,text ="Show selection", command =show).grid()
    
#     #下拉选择菜单
#     if True:
        
#         var3 = tkinter.StringVar()
#         var3.set("请选择")
#         dayoptions = [
#             "Monday",
#         "Tuesday",
#         "Wednesday",
#         "Thurday",
#         "Friday",
#         "Saturday",
#         "Sunday"]
# #         drop = tkinter.OptionMenu(root,var3,"Monday","Tuesday","Wednesday","Thurday","Friday","Saturday","Sunday").grid()      
#         drop = tkinter.OptionMenu(root,var3,*dayoptions).grid()



#         保持根窗口
        rootWindow.mainloop()

# %% [markdown]
# # !/usr/bin/python
# # -*- coding: utf-8 -*-
# import sys,time
# sys.modules
#
#
# def updataroot():
#     global frame_3
#     frame_3.destroy()
#
#
#         #创建板块框_3
#     frame_3 = tkinter.LabelFrame( root , font=('微软雅黑',14),bg="white",fg="#008080" )
#     frame_3.grid(row = 3, column = 0, rowspan=9,columnspan=2,padx=5, pady=5,ipadx=5, ipady=5,sticky = tkinter.W)
#
#     #布置 —— 按钮板块_2
#     # 按钮 —— 数字7
#     frame3_button_num1 = tkinter.Button(frame_3,text = '7',command=lambda:frame1_entry_1.insert("end",7))
#     frame3_button_num1.grid(row =0 ,column=1, padx=5, pady=5)
#     # 按钮 —— 数字8
#     frame3_button_num2 = tkinter.Button(frame_3,text = '8',command=lambda:frame1_entry_1.insert("end",8) )
#     frame3_button_num2.grid(row =0 ,column=2, padx=5, pady=5)
#     # 按钮 —— 数字9
#     frame3_button_num3 = tkinter.Button(frame_3,text = '9',command=lambda:frame1_entry_1.insert("end",9) )
#     frame3_button_num3.grid(row = 0,column=3, padx=5, pady=5)
#
#     # 按钮 —— 数字4
#     frame3_button_num4 = tkinter.Button(frame_3,text = '4',command=lambda:frame1_entry_1.insert("end",4) )
#     frame3_button_num4.grid(row = 1,column=1, padx=5, pady=5)
#     # 按钮 —— 数字5
#     frame3_button_num5 = tkinter.Button(frame_3,text = '5',command=lambda:frame1_entry_1.insert("end",5) )
#     frame3_button_num5.grid(row =1 ,column=2, padx=5, pady=5)
#     # 按钮 —— 数字6
#     frame3_button_num6 = tkinter.Button(frame_3,text = '6',command=lambda:frame1_entry_1.insert("end",6) )
#     frame3_button_num6.grid(row = 1,column=3, padx=5, pady=5)
#
#     # 按钮 —— 数字1
#     frame3_button_num7 = tkinter.Button(frame_3,text = '1',command=lambda:frame1_entry_1.insert("end",1) )
#     frame3_button_num7.grid(row =2 ,column=1, padx=5, pady=5)
#     # 按钮 —— 数字2
#     frame3_button_num8 = tkinter.Button(frame_3,text = '2',command=lambda:frame1_entry_1.insert("end",2) )
#     frame3_button_num8.grid(row =2 ,column=2, padx=5, pady=5)
#     # 按钮 —— 数字3
#     frame3_button_num9 = tkinter.Button(frame_3,text = '3',command=lambda:frame1_entry_1.insert("end",3) )
#     frame3_button_num9.grid(row =2 ,column=3, padx=5, pady=5)
#
#     # 按钮 —— 数字0
#     frame3_button_num0 = tkinter.Button(frame_3,text = '0',command=lambda:frame1_entry_1.insert("end",0) )
#     frame3_button_num0.grid(row =3,column=1, padx=5, pady=5)
#
#
#     #点击数字按钮时，在显示框的末尾插入
#     def keyboard_click(event):
#         mylabel1 = tkinter.Label( frame_3 ,text = ("鼠标的位置：" , event.x, event.y ), font=('微软雅黑',14),bg="white",fg="#008080" )
#         mylabel2 = tkinter.Label( frame_3 ,text = ("敲击的键：" , event.keysym ), font=('微软雅黑',14),bg="white",fg="#008080" )
#         mylabel1.grid()
#         mylabel2.grid()
#
#     # 鼠标 在 计算器键盘_3 板块内移动
#     frame_3.bind('<Motion>',keyboard_click)
#
#
#     # 按钮 —— Enter
#     frame3_button_numenter = tkinter.Button(frame_3,text = 'Enter')
#     frame3_button_numenter.grid(row =4,column=1,columnspan = 3, padx=5, pady=5)
#
#     #鼠标离开按钮范围
#     frame3_button_numenter.bind("<Leave>", keyboard_click)
#     #鼠标进入按钮范围
#     frame3_button_numenter.bind("<Enter>",keyboard_click)
#     #鼠标左键单击
#     frame3_button_numenter.bind("<Button-1>",keyboard_click)
#     #鼠标右键单击
#     frame3_button_numenter.bind("<Button-3>",keyboard_click)
#
#     #键盘按键
#     frame3_button_numenter.bind('<Key>',keyboard_click)
#     #键盘注焦，键盘按键事件才有效
#     frame3_button_numenter.focus_set()
#
#
#
#
#     root.after(5000,updataroot)
#
#
#
#
#
#
#
#
#
#
#
# #主程序区域
# if __name__ == "__main__":
# #主窗口界面编辑
#     import tkinter
#     # 创建主窗口
#     root = tkinter.Tk()
#     # 设置主窗口标题
#     root.title( "文件合并助手" )
#     # 设置主窗口图标
#     root.iconbitmap( r"root.ico" )
#     # 设置主窗口（'宽 x 高 + 偏右 + 偏下'）
#     root.geometry( "480x270+250+150" )
#
#     #主窗口布置
#     if True:
#
#         #菜单设置
#         if True:
#             #生成菜单
#             menu = tkinter.Menu( root )
#
#             #生成下拉菜单1
#             submenu = tkinter.Menu( menu , tearoff = 0 )
#             #在下拉菜单中添加
#             submenu.add_command( label = "Open" )
#             submenu.add_command( label = "Exit" ,command = lambda:root.destroy() )
#             #将（下拉菜单1）添加到（菜单）中
#             menu.add_cascade( label = "File" , menu = submenu )
#
#             #生成下拉菜单2
#             submenu = tkinter.Menu( menu , tearoff = 0 )
#             #在下拉菜单中添加
#             submenu.add_command( label = "Close" )
#             #将（下拉菜单1）添加到（菜单）中
#             menu.add_cascade( label = "Edit" , menu = submenu )
#
#             #确认（菜单）在主窗口显示
#             root.config( menu = menu )
#
#
#         #界面板块_1
#         if True:
#             #创建板块框_1
#             frame_1 = tkinter.LabelFrame( root , font=('微软雅黑',14),bg="white",fg="#008080")
#             frame_1.grid(row = 0,column = 0, rowspan=2,columnspan=2,padx=5, pady=5,ipadx=5, ipady=5)
#
#             # 布置 —— 界面板块_1
#             #提示输入根目录的标签
#             frame1_label_1 = tkinter.Label(frame_1,text = '文件所在目录：',font=('微软雅黑',14),fg="white",bg="#008080")
#             frame1_label_1.grid(row = 0,column=0, padx=5, pady=5)
#             #设置根目录输入框
#             #创建可变的字符串frame1_stringvar_1
#             frame1_stringvar_1 = tkinter.StringVar()
#             # frame1_stringvar_1 设置默认值
#             frame1_stringvar_1.set(r'E:\Python Working')
#             #设置输入框frame1_entry_1，文本引用可变字符串frame1_stringvar_1
#             frame1_entry_1 = tkinter.Entry( frame_1 ,textvariable=frame1_stringvar_1,font=('微软雅黑',14))
#             #在主窗口（第 1 行，第 2 列）展示输入框entry_0_1
#             frame1_entry_1.grid(row = 0, column = 1 , padx=5, pady=5)
#
#         #按钮板块_2
#         if True:
#             #创建板块框_2
#             frame_2 = tkinter.LabelFrame( root , font=('微软雅黑',14),bg="white",fg="#008080" )
#             frame_2.grid(row = 0, column = 2, rowspan=2,columnspan=2,padx=5, pady=5,ipadx=5, ipady=5)
#
#             #布置 —— 按钮板块_2
#             # 按钮 —— 清空输入框
#             frame2_button_clear = tkinter.Button(frame_2,text = '清空输入框',command=lambda:frame1_entry_1.delete(0,'end') )
#             frame2_button_clear.grid(row = 1,column=0, padx=5, pady=5)
#             # 按钮 —— 退出程序
#             frame2_button_destroy=tkinter.Button(frame_2,text = '退出程序',command=lambda:root.destroy())
#             frame2_button_destroy.grid(row = 0,column=0, padx=5, pady=5)
#
#         #计算器键盘_3
#         if True:
#             #创建板块框_3
#             frame_3 = tkinter.LabelFrame( root , font=('微软雅黑',14),bg="white",fg="#008080" )
#             frame_3.grid(row = 3, column = 0, rowspan=9,columnspan=2,padx=5, pady=5,ipadx=5, ipady=5,sticky = tkinter.W)
#
#             #布置 —— 按钮板块_2
#             # 按钮 —— 数字7
#             frame3_button_num1 = tkinter.Button(frame_3,text = '7',command=lambda:frame1_entry_1.insert("end",7))
#             frame3_button_num1.grid(row =0 ,column=1, padx=5, pady=5)
#             # 按钮 —— 数字8
#             frame3_button_num2 = tkinter.Button(frame_3,text = '8',command=lambda:frame1_entry_1.insert("end",8) )
#             frame3_button_num2.grid(row =0 ,column=2, padx=5, pady=5)
#             # 按钮 —— 数字9
#             frame3_button_num3 = tkinter.Button(frame_3,text = '9',command=lambda:frame1_entry_1.insert("end",9) )
#             frame3_button_num3.grid(row = 0,column=3, padx=5, pady=5)
#
#             # 按钮 —— 数字4
#             frame3_button_num4 = tkinter.Button(frame_3,text = '4',command=lambda:frame1_entry_1.insert("end",4) )
#             frame3_button_num4.grid(row = 1,column=1, padx=5, pady=5)
#             # 按钮 —— 数字5
#             frame3_button_num5 = tkinter.Button(frame_3,text = '5',command=lambda:frame1_entry_1.insert("end",5) )
#             frame3_button_num5.grid(row =1 ,column=2, padx=5, pady=5)
#             # 按钮 —— 数字6
#             frame3_button_num6 = tkinter.Button(frame_3,text = '6',command=lambda:frame1_entry_1.insert("end",6) )
#             frame3_button_num6.grid(row = 1,column=3, padx=5, pady=5)
#
#             # 按钮 —— 数字1
#             frame3_button_num7 = tkinter.Button(frame_3,text = '1',command=lambda:frame1_entry_1.insert("end",1) )
#             frame3_button_num7.grid(row =2 ,column=1, padx=5, pady=5)
#             # 按钮 —— 数字2
#             frame3_button_num8 = tkinter.Button(frame_3,text = '2',command=lambda:frame1_entry_1.insert("end",2) )
#             frame3_button_num8.grid(row =2 ,column=2, padx=5, pady=5)
#             # 按钮 —— 数字3
#             frame3_button_num9 = tkinter.Button(frame_3,text = '3',command=lambda:frame1_entry_1.insert("end",3) )
#             frame3_button_num9.grid(row =2 ,column=3, padx=5, pady=5)
#
#             # 按钮 —— 数字0
#             frame3_button_num0 = tkinter.Button(frame_3,text = '0',command=lambda:frame1_entry_1.insert("end",0) )
#             frame3_button_num0.grid(row =3,column=1, padx=5, pady=5)
#
#
#             #点击数字按钮时，在显示框的末尾插入
#             def keyboard_click(event):
#                 mylabel1 = tkinter.Label( frame_3 ,text = ("鼠标的位置：" , event.x, event.y ), font=('微软雅黑',14),bg="white",fg="#008080" )
#                 mylabel2 = tkinter.Label( frame_3 ,text = ("敲击的键：" , event.keysym ), font=('微软雅黑',14),bg="white",fg="#008080" )
#                 mylabel1.grid()
#                 mylabel2.grid()
#
#             # 鼠标 在 计算器键盘_3 板块内移动
#             frame_3.bind('<Motion>',keyboard_click)
#
#
#             # 按钮 —— Enter
#             frame3_button_numenter = tkinter.Button(frame_3,text = 'Enter')
#             frame3_button_numenter.grid(row =4,column=1,columnspan = 3, padx=5, pady=5)
#
#             #鼠标离开按钮范围
#             frame3_button_numenter.bind("<Leave>", keyboard_click)
#             #鼠标进入按钮范围
#             frame3_button_numenter.bind("<Enter>",keyboard_click)
#             #鼠标左键单击
#             frame3_button_numenter.bind("<Button-1>",keyboard_click)
#             #鼠标右键单击
#             frame3_button_numenter.bind("<Button-3>",keyboard_click)
#
#             #键盘按键
#             frame3_button_numenter.bind('<Key>',keyboard_click)
#             #键盘注焦，键盘按键事件才有效
#             frame3_button_numenter.focus_set()
#
#
#
# #     f222rame_3 = tkinter.Toplevel( root )
# #     f222rame_3.title("jiojoasjdofjods")
# #     f222rame_3.geometry("250x150")
#
#
#
# #     #点击主窗口 红叉 时，不关闭窗口而 弹出提示框
# #     import tkinter.messagebox
# #     def close_windows():
# #         tkinter.messagebox.showerror("提示一下","再细细想想~~！")
# #     root.protocol("WM_DELETE_WINDOW",lambda:close_windows())
#
#
# #     vertical1 = tkinter.Scale(root, from_=0 , to = 100)
# #     vertical1.grid()
# #     #水平
# #     horizontal1 = tkinter.Scale(root, from_=0 , to = 300,orient="horizontal")
# #     horizontal1.grid()
#
# #     #单选框
# #     if True:
# #         def show():
# #             malabel12 = tkinter.Label(root, text = var1.get()).grid()
#
# # #         var1 = tkinter.IntVar()
# # #         c = tkinter.Checkbutton(root,text ="Check this box", variable = var1).grid()
# #         var1 = tkinter.StringVar()
# #         c12 = tkinter.Checkbutton(root,text ="Check this box", variable = var1,onvalue = "On",offvalue="Off")
# #         c12.deselect()
# #         c12.grid()
#
# #         d = tkinter.Button(root,text ="Show selection", command =show).grid()
#
#     #下拉选择菜单
#     if True:
#
#         var3 = tkinter.StringVar()
#         var3.set("请选择")
#         dayoptions = [
#             "Monday",
#         "Tuesday",
#         "Wednesday",
#         "Thurday",
#         "Friday",
#         "Saturday",
#         "Sunday"]
# #         drop = tkinter.OptionMenu(root,var3,"Monday","Tuesday","Wednesday","Thurday","Friday","Saturday","Sunday").grid()
#         drop = tkinter.OptionMenu(root,var3,*dayoptions).grid()
#
#
#
#     #隐藏窗口
# #     root.withdraw()
# #     #窗口再显
# #     root.deiconify()
# #     #关闭窗口
# #     root.destroy()
#
#
# #更新窗口
# updataroot()
#
# #     #保持窗口
# # root.mainloop()
